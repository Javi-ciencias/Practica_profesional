# %%
import numpy as np

# %%
for i in range(1,30):
    print("Compute WT_40_"+str(i)+"_2= $sysmis.")
    print("Execute.")
    print("Compute WT_40_"+str(i)+"_3= $sysmis.")
    print("Execute.")
    print("Compute WT_40_"+str(i)+"_4= $sysmis.")
    print("Execute.")
    print("Compute WT_40_"+str(i)+"_5= $sysmis.")
    print("Execute.")
# Out:
# Compute WT_40_1_2= $sysmis.
# Execute.
# Compute WT_40_1_3= $sysmis.
# Execute.
# Compute WT_40_1_4= $sysmis.
# Execute.
# Compute WT_40_1_5= $sysmis.
# Execute.
# Compute WT_40_2_2= $sysmis.
# Execute.
# Compute WT_40_2_3= $sysmis.
# Execute.
# Compute WT_40_2_4= $sysmis.
# Execute.
# Compute WT_40_2_5= $sysmis.
# Execute.
# Compute WT_40_3_2= $sysmis.
# Execute.
# Compute WT_40_3_3= $sysmis.
# Execute.
# Compute WT_40_3_4= $sysmis.
# Execute.
# Compute WT_40_3_5= $sysmis.
# Execute.
# Compute WT_40_4_2= $sysmis.
# Execute.
# Compute WT_40_4_3= $sysmis.
# Execute.
# Compute WT_40_4_4= $sysmis.
# Execute.
# Compute WT_40_4_5= $sysmis.
# Execute.
# Compute WT_40_5_2= $sysmis.
# Execute.
# Compute WT_40_5_3= $sysmis.
# Execute.
# Compute WT_40_5_4= $sysmis.
# Execute.
# Compute WT_40_5_5= $sysmis.
# Execute.
# Compute WT_40_6_2= $sysmis.
# Execute.
# Compute WT_40_6_3= $sysmis.
# Execute.
# Compute WT_40_6_4= $sysmis.
# Execute.
# Compute WT_40_6_5= $sysmis.
# Execute.
# ...
